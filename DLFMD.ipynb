# %%
# !pip install tensorflow==2.12
# Out:
# Collecting tensorflow==2.12
#   Downloading tensorflow-2.12.0-cp39-cp39-win_amd64.whl.metadata (2.5 kB)
# Collecting tensorflow-intel==2.12.0 (from tensorflow==2.12)
#   Downloading tensorflow_intel-2.12.0-cp39-cp39-win_amd64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12) (25.9.23)
# Collecting gast<=0.4.0,>=0.2.1 (from tensorflow-intel==2.12.0->tensorflow==2.12)
#   Using cached gast-0.4.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12) (3.14.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12) (0.4.30)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12) (18.1.1)
# Collecting numpy<1.24,>=1.22 (from tensorflow-intel==2.12.0->tensorflow==2.12)
#   Downloading numpy-1.23.5-cp39-cp39-win_amd64.whl.metadata (2.3 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12) (3.4.0)
# Requirement already satisfied: packaging in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12) (25.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-intel==2.12.0->tensorflow==2.12)
#   Using cached protobuf-4.25.8-cp39-cp39-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12) (4.15.0)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow-intel==2.12.0->tensorflow==2.12)
#   Using cached wrapt-1.14.2-cp39-cp39-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12) (1.76.0)
# Collecting tensorboard<2.13,>=2.12 (from tensorflow-intel==2.12.0->tensorflow==2.12)
#   Using cached tensorboard-2.12.3-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12) (2.12.0)
# Collecting keras<2.13,>=2.12.0 (from tensorflow-intel==2.12.0->tensorflow==2.12)
#   Using cached keras-2.12.0-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12) (0.31.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12) (2.43.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12) (3.9)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12) (2.32.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12) (3.1.4)
# Requirement already satisfied: wheel>=0.26 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12) (0.45.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12) (2.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12) (2025.11.12)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12) (0.6.1)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow==2.12) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow==2.12) (0.5.4)
# Collecting scipy>=1.9 (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow==2.12)
#   Using cached scipy-1.13.1-cp39-cp39-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow==2.12) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from importlib-metadata>=4.6->jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow==2.12) (3.23.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12) (3.3.1)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12) (3.0.3)
# Downloading tensorflow-2.12.0-cp39-cp39-win_amd64.whl (1.9 kB)
# Downloading tensorflow_intel-2.12.0-cp39-cp39-win_amd64.whl (272.8 MB)
#    ---------------------------------------- 0.0/272.8 MB ? eta -:--:--
#    ---------------------------------------- 2.4/272.8 MB 22.6 MB/s eta 0:00:12
#    - -------------------------------------- 10.5/272.8 MB 34.5 MB/s eta 0:00:08
#    --- ------------------------------------ 23.6/272.8 MB 45.3 MB/s eta 0:00:06
#    ----- ---------------------------------- 35.4/272.8 MB 48.9 MB/s eta 0:00:05
#    ------ --------------------------------- 46.7/272.8 MB 50.4 MB/s eta 0:00:05
#    ------- -------------------------------- 51.6/272.8 MB 45.7 MB/s eta 0:00:05
#    -------- ------------------------------- 56.1/272.8 MB 42.0 MB/s eta 0:00:06
#    -------- ------------------------------- 61.3/272.8 MB 39.9 MB/s eta 0:00:06
#    --------- ------------------------------ 67.1/272.8 MB 38.2 MB/s eta 0:00:06
#    ---------- ----------------------------- 72.9/272.8 MB 37.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 78.9/272.8 MB 36.5 MB/s eta 0:00:06
#    ------------ --------------------------- 85.2/272.8 MB 36.0 MB/s eta 0:00:06
#    ------------- -------------------------- 92.3/272.8 MB 35.9 MB/s eta 0:00:06
#    -------------- ------------------------- 99.4/272.8 MB 35.6 MB/s eta 0:00:05
#    --------------- ----------------------- 107.0/272.8 MB 35.9 MB/s eta 0:00:05
#    ---------------- ---------------------- 114.8/272.8 MB 36.1 MB/s eta 0:00:05
#    ----------------- --------------------- 123.2/272.8 MB 36.4 MB/s eta 0:00:05
#    ------------------ -------------------- 131.1/272.8 MB 36.4 MB/s eta 0:00:04
#    ------------------- ------------------- 139.7/272.8 MB 36.7 MB/s eta 0:00:04
#    --------------------- ----------------- 148.6/272.8 MB 37.1 MB/s eta 0:00:04
#    ---------------------- ---------------- 157.5/272.8 MB 37.4 MB/s eta 0:00:04
#    ----------------------- --------------- 166.7/272.8 MB 37.8 MB/s eta 0:00:03
#    ------------------------ -------------- 174.9/272.8 MB 37.9 MB/s eta 0:00:03
#    -------------------------- ------------ 184.8/272.8 MB 38.2 MB/s eta 0:00:03
#    --------------------------- ----------- 193.7/272.8 MB 38.5 MB/s eta 0:00:03
#    ---------------------------- ---------- 200.0/272.8 MB 38.2 MB/s eta 0:00:02
#    ------------------------------ -------- 210.2/272.8 MB 38.6 MB/s eta 0:00:02
#    ------------------------------- ------- 218.6/272.8 MB 38.6 MB/s eta 0:00:02
#    -------------------------------- ------ 223.9/272.8 MB 38.2 MB/s eta 0:00:02
#    -------------------------------- ------ 229.4/272.8 MB 37.8 MB/s eta 0:00:02
#    --------------------------------- ----- 235.1/272.8 MB 37.5 MB/s eta 0:00:02
#    ---------------------------------- ---- 241.7/272.8 MB 37.2 MB/s eta 0:00:01
#    ----------------------------------- --- 249.0/272.8 MB 37.1 MB/s eta 0:00:01
#    ------------------------------------ -- 256.1/272.8 MB 37.1 MB/s eta 0:00:01
#    ------------------------------------- - 263.2/272.8 MB 37.2 MB/s eta 0:00:01
#    --------------------------------------  271.1/272.8 MB 37.3 MB/s eta 0:00:01
#    --------------------------------------  272.6/272.8 MB 37.2 MB/s eta 0:00:01
#    --------------------------------------  272.6/272.8 MB 37.2 MB/s eta 0:00:01
#    --------------------------------------  272.6/272.8 MB 37.2 MB/s eta 0:00:01
#    ---------------------------------------- 272.8/272.8 MB 33.8 MB/s  0:00:08
# Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Using cached keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
# Downloading numpy-1.23.5-cp39-cp39-win_amd64.whl (14.7 MB)
#    ---------------------------------------- 0.0/14.7 MB ? eta -:--:--
#    ---------------------- ----------------- 8.1/14.7 MB 41.8 MB/s eta 0:00:01
#    ---------------------------------------- 14.7/14.7 MB 36.9 MB/s  0:00:00
# Using cached protobuf-4.25.8-cp39-cp39-win_amd64.whl (413 kB)
# Using cached tensorboard-2.12.3-py3-none-any.whl (5.6 MB)
# Using cached wrapt-1.14.2-cp39-cp39-win_amd64.whl (35 kB)
# Using cached scipy-1.13.1-cp39-cp39-win_amd64.whl (46.2 MB)
# Installing collected packages: wrapt, protobuf, numpy, keras, gast, scipy, tensorboard, tensorflow-intel, tensorflow
#
#   Attempting uninstall: wrapt
#
#     Found existing installation: wrapt 2.0.1
#
#     Uninstalling wrapt-2.0.1:
#
#       Successfully uninstalled wrapt-2.0.1
#
#   Attempting uninstall: protobuf
#
#     Found existing installation: protobuf 6.33.2
#
#     Uninstalling protobuf-6.33.2:
#
#       Successfully uninstalled protobuf-6.33.2
#
#    ---- ----------------------------------- 1/9 [protobuf]
#    ---- ----------------------------------- 1/9 [protobuf]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#    -------- ------------------------------- 2/9 [numpy]
#   Attempting uninstall: keras
#    -------- ------------------------------- 2/9 [numpy]
#     Found existing installation: keras 3.10.0
#    -------- ------------------------------- 2/9 [numpy]
#    ------------- -------------------------- 3/9 [keras]
#     Uninstalling keras-3.10.0:
#    ------------- -------------------------- 3/9 [keras]
#       Successfully uninstalled keras-3.10.0
#    ------------- -------------------------- 3/9 [keras]
#    ------------- -------------------------- 3/9 [keras]
#    ------------- -------------------------- 3/9 [keras]
#    ------------- -------------------------- 3/9 [keras]
#    ------------- -------------------------- 3/9 [keras]
#    ------------- -------------------------- 3/9 [keras]
#    ------------- -------------------------- 3/9 [keras]
#    ------------- -------------------------- 3/9 [keras]
#    ------------- -------------------------- 3/9 [keras]
#    ------------- -------------------------- 3/9 [keras]
#    ------------- -------------------------- 3/9 [keras]
#    ------------- -------------------------- 3/9 [keras]
#    ------------- -------------------------- 3/9 [keras]
#    ------------- -------------------------- 3/9 [keras]
#    ------------- -------------------------- 3/9 [keras]
#   Attempting uninstall: gast
#    ------------- -------------------------- 3/9 [keras]
#     Found existing installation: gast 0.7.0
#    ------------- -------------------------- 3/9 [keras]
#     Uninstalling gast-0.7.0:
#    ------------- -------------------------- 3/9 [keras]
#       Successfully uninstalled gast-0.7.0
#    ------------- -------------------------- 3/9 [keras]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#    ---------------------- ----------------- 5/9 [scipy]
#   Attempting uninstall: tensorboard
#    ---------------------- ----------------- 5/9 [scipy]
#     Found existing installation: tensorboard 2.20.0
#    ---------------------- ----------------- 5/9 [scipy]
#     Uninstalling tensorboard-2.20.0:
#    ---------------------- ----------------- 5/9 [scipy]
#       Successfully uninstalled tensorboard-2.20.0
#    ---------------------- ----------------- 5/9 [scipy]
#    -------------------------- ------------- 6/9 [tensorboard]
#    -------------------------- ------------- 6/9 [tensorboard]
#    -------------------------- ------------- 6/9 [tensorboard]
#    -------------------------- ------------- 6/9 [tensorboard]
#    -------------------------- ------------- 6/9 [tensorboard]
#    -------------------------- ------------- 6/9 [tensorboard]
#    -------------------------- ------------- 6/9 [tensorboard]
#   Attempting uninstall: tensorflow-intel
#    -------------------------- ------------- 6/9 [tensorboard]
#     Found existing installation: tensorflow-intel 2.12.1
#    -------------------------- ------------- 6/9 [tensorboard]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#     Uninstalling tensorflow-intel-2.12.1:
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#       Successfully uninstalled tensorflow-intel-2.12.1
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ------------------------------- -------- 7/9 [tensorflow-intel]
#    ---------------------------------------- 9/9 [tensorflow]
#
# Successfully installed gast-0.4.0 keras-2.12.0 numpy-1.23.5 protobuf-4.25.8 scipy-1.13.1 tensorboard-2.12.3 tensorflow-2.12.0 tensorflow-intel-2.12.0 wrapt-1.14.2

# %%
import tensorflow as tf

# %%
# !pip install numpy==1.23
# !pip install matplotlib==3.9.4
# Out:
# Collecting numpy==1.23
#   Downloading numpy-1.23.0-cp39-cp39-win_amd64.whl.metadata (2.2 kB)
# Downloading numpy-1.23.0-cp39-cp39-win_amd64.whl (14.7 MB)
#    ---------------------------------------- 0.0/14.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/14.7 MB 16.9 MB/s eta 0:00:01
#    -- ------------------------------------- 1.0/14.7 MB 12.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 2.1/14.7 MB 4.7 MB/s eta 0:00:03
#    ----- ---------------------------------- 2.1/14.7 MB 4.7 MB/s eta 0:00:03
#    -------- ------------------------------- 3.1/14.7 MB 3.8 MB/s eta 0:00:04
#    -------------- ------------------------- 5.2/14.7 MB 4.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 6.3/14.7 MB 5.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 6.6/14.7 MB 4.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 8.4/14.7 MB 5.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 10.5/14.7 MB 5.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 10.5/14.7 MB 5.6 MB/s eta 0:00:01
#    ------------------------------- -------- 11.5/14.7 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 12.6/14.7 MB 5.0 MB/s eta 0:00:01
#    ------------------------------------- -- 13.6/14.7 MB 4.9 MB/s eta 0:00:01
#    ------------------------------------- -- 13.6/14.7 MB 4.9 MB/s eta 0:00:01
#    ------------------------------------- -- 13.6/14.7 MB 4.9 MB/s eta 0:00:01
#    ------------------------------------- -- 13.6/14.7 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 14.7/14.7 MB 4.1 MB/s  0:00:03
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
# Successfully installed numpy-1.23.0
# Requirement already satisfied: matplotlib==3.9.4 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from matplotlib==3.9.4) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from matplotlib==3.9.4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from matplotlib==3.9.4) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from matplotlib==3.9.4) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from matplotlib==3.9.4) (1.23.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from matplotlib==3.9.4) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from matplotlib==3.9.4) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from matplotlib==3.9.4) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from matplotlib==3.9.4) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from matplotlib==3.9.4) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from importlib-resources>=3.2.0->matplotlib==3.9.4) (3.23.0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.9.4) (1.17.0)

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\admin\anaconda3\envs\aidl\lib\site-packages (from opencv-python) (1.23.0)

# %%
import os
import cv2
import numpy as np
# !pip install keras==2.13

from keras.utils import to_categorical 
from keras.models import Sequential 
from keras.layers import Con2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
# Out:
# ERROR: Ignored the following versions that require a different python version: 3.11.0 Requires-Python >=3.10; 3.11.1 Requires-Python >=3.10; 3.11.2 Requires-Python >=3.10; 3.11.3 Requires-Python >=3.10; 3.12.0 Requires-Python >=3.10
# ERROR: Could not find a version that satisfies the requirement keras==2.13 (from versions: 0.2.0, 0.3.0, 0.3.1, 0.3.2, 0.3.3, 1.0.0, 1.0.1, 1.0.2, 1.0.3, 1.0.4, 1.0.5, 1.0.6, 1.0.7, 1.0.8, 1.1.0, 1.1.1, 1.1.2, 1.2.0, 1.2.1, 1.2.2, 2.0.0, 2.0.1, 2.0.2, 2.0.3, 2.0.4, 2.0.5, 2.0.6, 2.0.7, 2.0.8, 2.0.9, 2.1.0, 2.1.1, 2.1.2, 2.1.3, 2.1.4, 2.1.5, 2.1.6, 2.2.0, 2.2.1, 2.2.2, 2.2.3, 2.2.4, 2.2.5, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.4.2, 2.4.3, 2.5.0rc0, 2.6.0rc0, 2.6.0rc1, 2.6.0rc2, 2.6.0rc3, 2.6.0, 2.7.0rc0, 2.7.0rc2, 2.7.0, 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.10.0rc0, 2.10.0rc1, 2.10.0, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0rc3, 2.11.0, 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.13.1rc0, 2.13.1rc1, 2.13.1, 2.14.0rc0, 2.14.0, 2.15.0rc0, 2.15.0rc1, 2.15.0, 3.0.0, 3.0.1, 3.0.2, 3.0.3, 3.0.4, 3.0.5, 3.1.0, 3.1.1, 3.2.0, 3.2.1, 3.3.0, 3.3.1, 3.3.2, 3.3.3, 3.4.0, 3.4.1, 3.5.0, 3.6.0, 3.7.0, 3.8.0, 3.9.0, 3.9.1, 3.9.2, 3.10.0)
# ERROR: No matching distribution found for keras==2.13
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 8
#       6 from keras.utils import to_categorical
#       7 from keras.models import Sequential
# ----> 8 from keras.layers import Con2D, MaxPooling2D, Flatten, Dense, Dropout
#       9 from keras.preprocessing.image import ImageDataGenerator
#      10 from keras.optimizers import Adam
#
# ImportError: cannot import name 'Con2D' from 'keras.layers' (C:\Users\Admin\anaconda3\envs\aidl\lib\site-packages\keras\layers\__init__.py)
